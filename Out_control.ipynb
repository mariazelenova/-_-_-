# %% [markdown]
# Списание просрочки
#
# Мысль такая что если списали в магазине, а не реализовали, значит что-то не так, и если это происходит с конкретными продуктами или при перемещении кем-то конкретным, значит, надо на это обратить внимание, может там фрод или другие нарушения закона.

# %% [markdown]
# Введено в оборот

# %% [markdown]
# ![введено в оборот.PNG](data:image/png;base64,...)

# %% [markdown]
# Перемещено между участниками

# %% [markdown]
# ![перемещено между участниками.PNG](data:image/png;base64,...)

# %% [markdown]
# выведено из оборота
#
# ![продажа.PNG](data:image/png;base64,...)

# %% [markdown]
# списано
#
# ![списание итог.PNG](data:image/png;base64,...)
